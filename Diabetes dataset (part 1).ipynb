# %%
#Load dataset
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np

diabetes = load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
X = df.copy()
y = pd.DataFrame(diabetes.target.copy(), columns=['target'])

# %%
#Basic informations on dataset
"""
X.info()
X.describe()

y.info()
y.describe()
"""
print(X.columns)
print(f'X.shape= {X.shape}, y.shape= {y.shape}')
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')
# X.shape= (442, 10), y.shape= (442, 1)

# %%
#Plot histograms of feature and target variables
X.hist()
y.hist()
# Out:
# array([[<Axes: title={'center': 'target'}>]], dtype=object)

# %%
#Plot seaborn pairplot to visualize relationships between combinations of features
sns.pairplot(X)

# %%
#Check correlation of features
cmap = sns.diverging_palette(h_neg=10, h_pos=240, as_cmap=True)
corr = X.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, mask=mask,
center=0, cmap=cmap, linewidths=1,
annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
#Scale target

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#m = MinMaxScaler(feature_range=(-0.1, 0.1))
#s = StandardScaler()
#y_scaled = s.fit_transform(y)
#y_m = m.fit_transform(y_scaled)
#y = pd.DataFrame(y_scaled, columns=['target'])
#y.hist()
# Out:
# array([[<Axes: title={'center': 'target'}>]], dtype=object)
